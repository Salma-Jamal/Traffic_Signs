# %%
import glob
from skimage.transform import resize
import numpy as np 
import pandas as pd 
import matplotlib
import matplotlib.pyplot as plt
import skimage.transform
import tensorflow as tf
import os
import cv2

# %%
tf.__version__
# Out:
# '1.14.0'

# %%
def read_dataset(Directory):

  labels = []
  images = []
  
  directories = [direc for direc in os.listdir(Directory) 
                   if os.path.isdir(os.path.join(Directory, direc))]

  for direc in directories:
        label = os.path.join(Directory, direc)
        img_names = [os.path.join(label, img) 
                      for img in os.listdir(label) if img.endswith(".ppm")]
       
        for img in img_names:
          imag = cv2.imread(img)
          imag = skimage.transform.resize(imag, (32, 32), mode='constant')
          images.append(imag)
          labels.append(int(direc))

  return images, labels

# %%
images, labels = read_dataset('C:/Users/DR.LAP/BelgiumTSC/BelgiumTSC/Training')
images_test, labels_test = read_dataset('C:/Users/DR.LAP/BelgiumTSC/BelgiumTSC/Testing')

# %%
print("Number Of Unique Labels: {0}\nTotal Images: {1}".format(len(set(labels)), len(images)))
# Out:
# Number Of Unique Labels: 62
# Total Images: 4575

# %%
np_labels = np.array(labels)
np_images = np.array(images)
print("labels: ", np_labels.shape, "\nimages: ", np_images.shape)
# Out:
# labels:  (4575,)
# images:  (4575, 32, 32, 3)

# %%
np_test_images = np.array(images_test)
np_test_labels = np.array(labels_test)
print("labels: ", np_test_labels.shape, "\nimages: ", np_test_images.shape)
# Out:
# labels:  (2520,)
# images:  (2520, 32, 32, 3)

# %%
labelsn= np.array(labels)
z=[]
for i in range(62):
  z.append(np.count_nonzero(labelsn == i))

# %%
def display_images(images, label):
    fig= plt.figure(figsize=(8,10))
    fig.patch.set_facecolor('grey')
    fig.patch.set_alpha(.3)
    image = labels.index(label)
    plt.title(label)
    plt.subplot(5, 4, 1)
    plt.axis('off') 
    plt.imshow(images[image+1])
    color='yellow'
    plt.text(-1, 50, "Sign From Class: {0} \nContains: {1} Image".format(label,z[label]),fontsize=16, color=color)
    plt.show()

# %%
#choose a label from 0 to 61 to plot photo
display_images(images, 44)

# %%
display_images(images, 5)

# %%
graph = tf.Graph()


with graph.as_default():
    
    images_ph = tf.placeholder(tf.float32, [None, 32, 32, 3])
    labels_ph = tf.placeholder(tf.int32, [None])

    
    images_flat = tf.contrib.layers.flatten(images_ph)

    
    logits = tf.contrib.layers.fully_connected(images_flat, 62, tf.nn.relu)

    
    predicted_labels = tf.argmax(logits, 1)

    
    loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=labels_ph))

    train = tf.train.AdamOptimizer(learning_rate=0.001).minimize(loss)

    init = tf.global_variables_initializer()

print("images_flat: ", images_flat)
print("logits: ", logits)
print("loss: ", loss)
print("predicted_labels: ", predicted_labels)
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From C:\Users\DR.LAP\Anaconda3\lib\site-packages\tensorflow\contrib\layers\python\layers\layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# images_flat:  Tensor("Flatten/flatten/Reshape:0", shape=(?, 3072), dtype=float32)
# logits:  Tensor("fully_connected/Relu:0", shape=(?, 62), dtype=float32)
# loss:  Tensor("Mean:0", shape=(), dtype=float32)
# predicted_labels:  Tensor("ArgMax:0", shape=(?,), dtype=int64)

# %%
session = tf.Session(graph=graph)
_ = session.run([init])

# %%
for i in range(201):
    _, loss_value = session.run([train, loss], feed_dict={images_ph: np_images, labels_ph: np_labels})
    if i % 10 == 0:
        print("Loss: ", loss_value)
# Out:
# Loss:  4.259822
# Loss:  2.9450498
# Loss:  2.444762
# Loss:  2.211066
# Loss:  2.0748205
# Loss:  1.9820952
# Loss:  1.9123708
# Loss:  1.8570093
# Loss:  1.8112079
# Loss:  1.7724574
# Loss:  1.7390682
# Loss:  1.7098498
# Loss:  1.6839244
# Loss:  1.6607838
# Loss:  1.6399833
# Loss:  1.6211549
# Loss:  1.6040182
# Loss:  1.5883493
# Loss:  1.5739615
# Loss:  1.5606991
# Loss:  1.5484266

# %%
predict_test = session.run([predicted_labels], feed_dict={images_ph: np_test_images})[0]

match_count = sum(
    [int(y == y_) 
     for y, y_ in zip(np_test_labels, predict_test)
    ]
)
accuracy = match_count / len(np_test_labels) *100
print("Accuracy: {:.3f}".format(accuracy))
# Out:
# Accuracy: 67.143

# %%
def plot_image(images_num):
  fig = plt.figure(figsize=(11, 10))
  real_label = np_test_labels[images_num]
  prediction = predict_test[images_num]
  predictedClassImgLabel = np.where(np_test_labels == prediction)
  ImgFromPredictedClass=predictedClassImgLabel[0][0]
  i=1
 
  for x in range(2):
    plt.subplot(5,2,i)
    plt.axis('off')
    plt.imshow(np_test_images[images_num])
    images_num = ImgFromPredictedClass
    i+=1
  color='purple' if real_label == prediction else 'yellow'
  plt.text(-75, 22, "True Label: {0} (Left Image)\nPredicted: {1} (Right Image)".format(real_label, prediction), 
             fontsize=14, color=color,bbox=dict(facecolor='black', alpha=0.4))
  plt.show()

# %%
plot_image(2)
plot_image(2320)
plot_image(1000)
plot_image(1305)

# %%
classes = []
for i in range(62):
    classes.append(i)

# %%
print(metrics.confusion_matrix(np_test_labels, predict_test, labels=classes))
# Out:
# [[  0   5   0 ...   0   0   0]
#  [  0  26   0 ...   0   0   1]
#  [  0   0   0 ...   0   0   1]
#  ...
#  [  0   1   0 ...  13   0   0]
#  [  0   0   0 ...   0   0   8]
#  [  0   0   0 ...   0   0 105]]

# %%
print(metrics.classification_report(np_test_labels, predict_test, labels=classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         6
#            1       0.55      0.96      0.70        27
#            2       0.00      0.00      0.00         7
#            3       0.00      0.00      0.00         6
#            4       0.00      0.00      0.00        12
#            5       0.00      0.00      0.00         3
#            6       0.00      0.00      0.00         6
#            7       0.62      0.92      0.74        90
#            8       0.00      0.00      0.00        12
#            9       0.00      0.00      0.00         0
#           10       0.00      0.00      0.00        28
#           11       0.00      0.00      0.00         0
#           12       0.00      0.00      0.00         3
#           13       0.46      0.69      0.55        39
#           14       0.00      0.00      0.00        15
#           15       0.00      0.00      0.00         0
#           16       0.00      0.00      0.00        12
#           17       0.88      0.97      0.92       183
#           18       0.83      0.83      0.83       122
#           19       0.86      0.99      0.92       163
#           20       0.00      0.00      0.00         3
#           21       0.00      0.00      0.00        45
#           22       0.57      1.00      0.73        61
#           23       0.00      0.00      0.00        15
#           24       0.75      0.69      0.72        13
#           25       0.00      0.00      0.00         3
#           26       0.00      0.00      0.00         0
#           27       0.00      0.00      0.00         9
#           28       0.41      0.94      0.57        51
#           29       0.96      0.96      0.96        28
#           30       0.00      0.00      0.00        37
#           31       0.00      0.00      0.00        86
#           32       0.75      0.98      0.85       422
#           33       0.00      0.00      0.00         0
#           34       0.00      0.00      0.00         9
#           35       0.00      0.00      0.00       154
#           36       0.00      0.00      0.00         0
#           37       0.00      0.00      0.00        31
#           38       0.63      0.94      0.75       213
#           39       0.72      0.95      0.82        99
#           40       0.65      0.92      0.76        48
#           41       0.69      1.00      0.81        11
#           42       0.00      0.00      0.00         9
#           43       0.00      0.00      0.00         6
#           44       0.27      1.00      0.43         3
#           45       0.00      0.00      0.00        84
#           46       0.00      0.00      0.00         6
#           47       0.67      1.00      0.81        31
#           48       0.00      0.00      0.00         0
#           49       0.00      0.00      0.00         3
#           50       0.00      0.00      0.00         0
#           51       0.00      0.00      0.00         3
#           52       0.00      0.00      0.00         0
#           53       0.00      0.00      0.00        24
#           54       0.00      0.00      0.00        48
#           55       0.00      0.00      0.00        15
#           56       0.48      1.00      0.65        33
#           57       0.48      0.54      0.51        41
#           58       0.00      0.00      0.00         9
#           59       0.33      0.76      0.46        17
#           60       0.00      0.00      0.00        11
#           61       0.58      1.00      0.73       105
#
#    micro avg       0.67      0.67      0.67      2520
#    macro avg       0.21      0.31      0.25      2520
# weighted avg       0.50      0.67      0.57      2520

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import metrics
cm=metrics.confusion_matrix(np_test_labels,predict_test,classes)

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_cm = pd.DataFrame(cm, classes,classes)
plt.figure(figsize = (20,20))
sn.heatmap(df_cm, annot=True, cmap=plt.cm.Blues)

# %%
session.close()
